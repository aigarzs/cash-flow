# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# Assuming you have a SQLAlchemy engine
# Replace 'sqlite:///your_database.db' with your actual database connection string
engine = create_engine('sqlite:///data/database.db')

# %%
# Step 1: Load the tables
definition_df = pd.read_sql_table("E01_CashFlowDefinition", engine)
definition_accounts_df = pd.read_sql_table('E01_CashFlowDefinitionAccounts', engine)
transactions_df = pd.read_sql_query('SELECT * FROM D12_CF_BankReceipts_Aggregated WHERE strftime("%Y", d_date) = "2024"', engine)

# %%
definition_df.head()
# Out:
#    id key                             text
# 0   1   k  saimnieciskās darbības ieņēmumi
# 1   2   l                    citi ieņēmumi
# 2   3   m         maksājumi par izejvielām
# 3   4   n                    PVN maksājumi

# %%
definition_accounts_df.head()
# Out:
#    id  definition_id operator entry_type account
# 0   1              1        +         CR    6110
# 1   8              2        +         CR    6550
# 2  10              3        -         DR    7110
# 3  11              3        -         DR    7210
# 4  12              4        -         DR    5721

# %%
transactions_df.head()
# Out:
#    d_id  d_type                      d_date  d_customer gl_account  \
# 0  1700       1  2024-01-03 00:00:00.000000          67       2310
# 1  1700       1  2024-01-03 00:00:00.000000          67       2620
# 2  1700       1  2024-01-03 00:00:00.000000          67       5721
# 3  1700       1  2024-01-03 00:00:00.000000          67       6110
# 4  1700       1  2024-01-03 00:00:00.000000          67       6550
#
#   gl_entry_type  gl_amount d_currency  gl_amount_LC
# 0            DR       0.00        EUR          0.00
# 1            DR    6736.19        EUR       6736.19
# 2            CR    1169.09        EUR       1169.09
# 3            CR    2376.03        EUR       2376.03
# 4            CR    3191.07        EUR       3191.07

# %%
# Step 2: Perform the LEFT JOIN on entry_type and account
# This will join all rows in definition with matching rows in transactions
definition_df = pd.merge(
    definition_df.rename(columns={"id":"definition_id"}),
    definition_accounts_df,
    on="definition_id")

# %%
definition_df.drop(columns=["id"], inplace=True)

# %%
definition_df.head()
# Out:
#    definition_id key                             text operator entry_type  \
# 0              1   k  saimnieciskās darbības ieņēmumi        +         CR
# 1              2   l                    citi ieņēmumi        +         CR
# 2              3   m         maksājumi par izejvielām        -         DR
# 3              3   m         maksājumi par izejvielām        -         DR
# 4              4   n                    PVN maksājumi        -         DR
#
#   account
# 0    6110
# 1    6550
# 2    7110
# 3    7210
# 4    5721

# %%
# This will join all rows in definition with matching rows in transactions

merged_df = definition_df.merge(
    transactions_df,
    left_on=['entry_type', 'account'],        # Columns in definition_df
    right_on=['gl_entry_type', 'gl_account'], # Corresponding columns in transactions_df
    how='left'
)

# %%
merged_df.head()
# Out:
#    definition_id key                             text operator entry_type  \
# 0              1   k  saimnieciskās darbības ieņēmumi        +         CR
# 1              1   k  saimnieciskās darbības ieņēmumi        +         CR
# 2              1   k  saimnieciskās darbības ieņēmumi        +         CR
# 3              1   k  saimnieciskās darbības ieņēmumi        +         CR
# 4              1   k  saimnieciskās darbības ieņēmumi        +         CR
#
#   account    d_id  d_type                      d_date  d_customer gl_account  \
# 0    6110  1700.0     1.0  2024-01-03 00:00:00.000000        67.0       6110
# 1    6110  2030.0     1.0  2024-01-03 00:00:00.000000        43.0       6110
# 2    6110  2031.0     1.0  2024-01-04 00:00:00.000000        70.0       6110
# 3    6110  1590.0     1.0  2024-01-05 00:00:00.000000        93.0       6110
# 4    6110  2333.0     1.0  2024-01-05 00:00:00.000000        67.0       6110
#
#   gl_entry_type  gl_amount d_currency  gl_amount_LC
# 0            CR    2376.03        EUR       2376.03
# 1            CR    6870.59        EUR       6870.59
# 2            CR      14.60        EUR         14.60
# 3            CR    5952.30        EUR       5952.30
# 4            CR    1731.35        EUR       1731.35

# %%
# Step 3: Apply the operator to the amount
# Use np.where to adjust the amount based on the operator column
merged_df['adjusted_amount'] = np.where(
    merged_df['operator'] == '+', 
    merged_df['gl_amount_LC'], 
    -merged_df['gl_amount_LC']
)

# %%
merged_df.head()
# Out:
#    id  definition_id operator entry_type account    d_id  d_type  \
# 0   1              1        +         CR    6110  1700.0     1.0
# 1   1              1        +         CR    6110  2030.0     1.0
# 2   1              1        +         CR    6110  2031.0     1.0
# 3   1              1        +         CR    6110  1590.0     1.0
# 4   1              1        +         CR    6110  2333.0     1.0
#
#                        d_date  d_customer gl_account gl_entry_type  gl_amount  \
# 0  2024-01-03 00:00:00.000000        67.0       6110            CR    2376.03
# 1  2024-01-03 00:00:00.000000        43.0       6110            CR    6870.59
# 2  2024-01-04 00:00:00.000000        70.0       6110            CR      14.60
# 3  2024-01-05 00:00:00.000000        93.0       6110            CR    5952.30
# 4  2024-01-05 00:00:00.000000        67.0       6110            CR    1731.35
#
#   d_currency  gl_amount_LC  adjusted_amount
# 0        EUR       2376.03          2376.03
# 1        EUR       6870.59          6870.59
# 2        EUR         14.60            14.60
# 3        EUR       5952.30          5952.30
# 4        EUR       1731.35          1731.35

# %%
# Step 4: Set up weekly periods for the transaction dates
# Convert `date` column to datetime if not already done
merged_df['d_date'] = pd.to_datetime(merged_df['d_date'])

# %%
merged_df.head()
# Out:
#    id  definition_id operator entry_type account    d_id  d_type     d_date  \
# 0   1              1        +         CR    6110  1700.0     1.0 2024-01-03
# 1   1              1        +         CR    6110  2030.0     1.0 2024-01-03
# 2   1              1        +         CR    6110  2031.0     1.0 2024-01-04
# 3   1              1        +         CR    6110  1590.0     1.0 2024-01-05
# 4   1              1        +         CR    6110  2333.0     1.0 2024-01-05
#
#    d_customer gl_account gl_entry_type  gl_amount d_currency  gl_amount_LC  \
# 0        67.0       6110            CR    2376.03        EUR       2376.03
# 1        43.0       6110            CR    6870.59        EUR       6870.59
# 2        70.0       6110            CR      14.60        EUR         14.60
# 3        93.0       6110            CR    5952.30        EUR       5952.30
# 4        67.0       6110            CR    1731.35        EUR       1731.35
#
#    adjusted_amount
# 0          2376.03
# 1          6870.59
# 2            14.60
# 3          5952.30
# 4          1731.35

# %%
# Calculate the week ending dates for each transaction
merged_df['week_end'] = merged_df['d_date'] + pd.offsets.Week(weekday=6)  # Week ends on Sunday
merged_df.head()
# Out:
#    id  definition_id operator entry_type account    d_id  d_type     d_date  \
# 0   1              1        +         CR    6110  1700.0     1.0 2024-01-03
# 1   1              1        +         CR    6110  2030.0     1.0 2024-01-03
# 2   1              1        +         CR    6110  2031.0     1.0 2024-01-04
# 3   1              1        +         CR    6110  1590.0     1.0 2024-01-05
# 4   1              1        +         CR    6110  2333.0     1.0 2024-01-05
#
#    d_customer gl_account gl_entry_type  gl_amount d_currency  gl_amount_LC  \
# 0        67.0       6110            CR    2376.03        EUR       2376.03
# 1        43.0       6110            CR    6870.59        EUR       6870.59
# 2        70.0       6110            CR      14.60        EUR         14.60
# 3        93.0       6110            CR    5952.30        EUR       5952.30
# 4        67.0       6110            CR    1731.35        EUR       1731.35
#
#    adjusted_amount   week_end
# 0          2376.03 2024-01-07
# 1          6870.59 2024-01-07
# 2            14.60 2024-01-07
# 3          5952.30 2024-01-07
# 4          1731.35 2024-01-07

# %%
# Step 5: Aggregate by week and row_id
# Group by row_id and week_end, summing the adjusted amounts
aggregated_df = (
    merged_df.groupby(['definition_id', 'week_end'])['adjusted_amount']
    .sum()
    .reset_index()
)
aggregated_df.head()
# Out:
#    definition_id   week_end  adjusted_amount
# 0              1 2024-01-07         16944.87
# 1              1 2024-01-14         11614.31
# 2              1 2024-01-21          7718.96
# 3              1 2024-01-28         10022.30
# 4              1 2024-02-11           214.36

# %%
# Step 6: Create a pivot table
# Pivot with row_id as rows, week_end as columns, and adjusted_amount as values
pivot_df = aggregated_df.pivot_table(
    index='definition_id',
    columns='week_end',
    values='adjusted_amount',
    fill_value=0
)
pivot_df.head()
# Out:
# week_end       2024-01-07  2024-01-14  2024-01-21  2024-01-28  2024-02-11  \
# definition_id
# 1                16944.87    11614.31     7718.96    10022.30      214.36
# 2                10861.16     9284.56     9524.83    12576.13      606.21
# 4                 5839.27     4388.76     3621.20     4745.66      172.32
#
# week_end       2024-02-18  2024-02-25  2024-03-03  2024-03-10  2024-03-24  \
# definition_id
# 1                 3284.94    15948.17     2978.20    10457.39     2768.05
# 2                16868.43    12804.67     3503.00    12920.20     4719.53
# 4                 4232.22     6038.09     1361.06     4909.30     1572.40
#
# week_end       ...  2024-10-27  2024-11-03  2024-11-10  2024-11-17  \
# definition_id  ...
# 1              ...     7852.09        0.00     1460.69       78.79
# 2              ...     9041.21     5330.33     4055.51     8314.51
# 4              ...     3547.60     1119.37     1158.40     1762.60
#
# week_end       2024-11-24  2024-12-01  2024-12-08  2024-12-15  2024-12-22  \
# definition_id
# 1                 5598.72     5956.23        0.00     6189.78     3156.65
# 2                 2755.92     2204.96     1403.99     7556.09     9379.13
# 4                 1754.47     1713.85      294.84     2886.63     2632.52
#
# week_end       2024-12-29
# definition_id
# 1                    0.00
# 2                13197.29
# 4                 2771.44
#
# [3 rows x 47 columns]

# %%
# Step 7: Ensure every week in 2024 is represented as a column
# Define all weeks in 2024 to create a complete set of columns
all_weeks = pd.date_range(start="2024-01-01", end="2024-12-31", freq='W-SUN')

# %%
# Reindex pivot table with all weeks in 2024 as columns
pivot_df = pivot_df.reindex(columns=all_weeks, fill_value=0)
pivot_df.head()
# Out:
#                2024-01-07  2024-01-14  2024-01-21  2024-01-28  2024-02-04  \
# definition_id
# 1                16944.87    11614.31     7718.96    10022.30           0
# 2                10861.16     9284.56     9524.83    12576.13           0
# 4                 5839.27     4388.76     3621.20     4745.66           0
#
#                2024-02-11  2024-02-18  2024-02-25  2024-03-03  2024-03-10  \
# definition_id
# 1                  214.36     3284.94    15948.17     2978.20    10457.39
# 2                  606.21    16868.43    12804.67     3503.00    12920.20
# 4                  172.32     4232.22     6038.09     1361.06     4909.30
#
#                ...  2024-10-27  2024-11-03  2024-11-10  2024-11-17  \
# definition_id  ...
# 1              ...     7852.09        0.00     1460.69       78.79
# 2              ...     9041.21     5330.33     4055.51     8314.51
# 4              ...     3547.60     1119.37     1158.40     1762.60
#
#                2024-11-24  2024-12-01  2024-12-08  2024-12-15  2024-12-22  \
# definition_id
# 1                 5598.72     5956.23        0.00     6189.78     3156.65
# 2                 2755.92     2204.96     1403.99     7556.09     9379.13
# 4                 1754.47     1713.85      294.84     2886.63     2632.52
#
#                2024-12-29
# definition_id
# 1                    0.00
# 2                13197.29
# 4                 2771.44
#
# [3 rows x 52 columns]

# %%
# Optional: Format column headers to display dates as strings (YYYY-MM-DD)
# Ensure columns are in datetime format before formatting
pivot_df.columns = pd.to_datetime(pivot_df.columns, errors='coerce')

# Format column headers to show only the date part
pivot_df.columns = [col.strftime('%Y-%m-%d') if not pd.isnull(col) else col for col in pivot_df.columns]
pivot_df.head()
# Out:
#                2024-01-07  2024-01-14  2024-01-21  2024-01-28  2024-02-04  \
# definition_id
# 1                16944.87    11614.31     7718.96    10022.30           0
# 2                10861.16     9284.56     9524.83    12576.13           0
# 4                 5839.27     4388.76     3621.20     4745.66           0
#
#                2024-02-11  2024-02-18  2024-02-25  2024-03-03  2024-03-10  \
# definition_id
# 1                  214.36     3284.94    15948.17     2978.20    10457.39
# 2                  606.21    16868.43    12804.67     3503.00    12920.20
# 4                  172.32     4232.22     6038.09     1361.06     4909.30
#
#                ...  2024-10-27  2024-11-03  2024-11-10  2024-11-17  \
# definition_id  ...
# 1              ...     7852.09        0.00     1460.69       78.79
# 2              ...     9041.21     5330.33     4055.51     8314.51
# 4              ...     3547.60     1119.37     1158.40     1762.60
#
#                2024-11-24  2024-12-01  2024-12-08  2024-12-15  2024-12-22  \
# definition_id
# 1                 5598.72     5956.23        0.00     6189.78     3156.65
# 2                 2755.92     2204.96     1403.99     7556.09     9379.13
# 4                 1754.47     1713.85      294.84     2886.63     2632.52
#
#                2024-12-29
# definition_id
# 1                    0.00
# 2                13197.29
# 4                 2771.44
#
# [3 rows x 52 columns]

# %%
a = pd.to_datetime("2024-11-17")
a
# Out:
# Timestamp('2024-11-17 00:00:00')

# %%
b = a + pd.offsets.Week(n=0, weekday=6)
b
# Out:
# Timestamp('2024-11-17 00:00:00')

# %%
c = pivot_df.iat[0, 4]
type(c)
# Out:
# numpy.int64

# %%
type(pivot_df.columns[1])
# Out:
# str
